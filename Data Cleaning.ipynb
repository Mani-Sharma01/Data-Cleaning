# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('archive.zip')

# %%
data
# Out:
#       Unnamed: 0       price  \
# 0              0   5600000.0
# 1              1   8800000.0
# 2              2  16500000.0
# 3              3   3810000.0
# 4              4   6200000.0
# ...          ...         ...
# 7733        7733   7900000.0
# 7734        7734   4510000.0
# 7735        7735   7000000.0
# 7736        7736   6500000.0
# 7737        7737   6500000.0
#
#                                                 Address    area   latitude  \
# 0                     Noida Extension, Noida, Delhi NCR  1350.0  28.608850
# 1                         Sector 79, Gurgaon, Delhi NCR  1490.0  28.374236
# 2                        Vaishali, Ghaziabad, Delhi NCR  2385.0  28.645769
# 3     Link Road, F Block, Sector 50, Noida, Uttar Pr...  1050.0  28.566914
# 4     Jaypee Pavilion Court Sector 128, Noida, Secto...  1350.0  28.520732
# ...                                                 ...     ...        ...
# 7733                  Indirapuram, Ghaziabad, Delhi NCR  1095.0  28.635272
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 329 entries, 10 to 7709
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        329 non-null    int64
#  1   price             329 non-null    float64
#  2   Address           329 non-null    object
#  3   area              329 non-null    float64
#  4   latitude          329 non-null    float64
#  5   longitude         329 non-null    float64
#  6   Bedrooms          329 non-null    float64
#  7   Bathrooms         329 non-null    float64
#  8   Balcony           329 non-null    float64
#  9   Status            329 non-null    object
#  10  neworold          329 non-null    object
#  11  parking           329 non-null    float64
#  12  Furnished_status  329 non-null    object
#  13  Lift              329 non-null    float64
#  14  Landmarks         329 non-null    object
#  15  type_of_building  329 non-null    object
# ...

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 329 entries, 10 to 7709
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        329 non-null    int64
#  1   price             329 non-null    float64
#  2   Address           329 non-null    object
#  3   area              329 non-null    float64
#  4   latitude          329 non-null    float64
#  5   longitude         329 non-null    float64
#  6   Bedrooms          329 non-null    float64
#  7   Bathrooms         329 non-null    float64
#  8   Balcony           329 non-null    float64
#  9   Status            329 non-null    object
#  10  neworold          329 non-null    object
#  11  parking           329 non-null    float64
#  12  Furnished_status  329 non-null    object
#  13  Lift              329 non-null    float64
#  14  Landmarks         329 non-null    object
#  15  type_of_building  329 non-null    object
# ...

# %%
from sklearn.model_selection import train_test_split

x= data.drop(['price'], axis=1)
y= data['price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
train_data = x_train.join(y_train)

# %%
train_data
# Out:
#       Unnamed: 0                                            Address    area  \
# 7134        7134                123., Sector 65, Gurgaon, Delhi NCR  1020.0
# 178          178  Swaroop garden gurgaon, Rajendra Park, Gurgaon...   540.0
# 2199        2199  84A, E-Block, Gali No. 6, Uttam Nagar West, Ne...   600.0
# 7180        7180                    Palam Vihar, Gurgaon, Delhi NCR  1980.0
# 6296        6296  A15 First floor near G D Goenka Public school ...  1700.0
# ...          ...                                                ...     ...
# 3140        3140  J5 block rajouri garden., Rajouri Garden Exten...  1500.0
# 5258        5258  Subhash Nagar, sector 7, near Raj Mahel hotel,...  1100.0
# 267          267  Sector 62Noida stellar park apartments, C Bloc...  1500.0
# 184          184  342 Durgapuri Extension Delhi India, Durgapuri...  1250.0
# 1710        1710  002, 95J, Bharat Residency, sector 15 part2, N...  1000.0
#
# ...

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'area'}>,
#         <AxesSubplot:title={'center':'latitude'}>],
#        [<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'Bedrooms'}>,
#         <AxesSubplot:title={'center':'Bathrooms'}>],
#        [<AxesSubplot:title={'center':'Balcony'}>,
#         <AxesSubplot:title={'center':'parking'}>,
#         <AxesSubplot:title={'center':'Lift'}>],
#        [<AxesSubplot:title={'center':'Price_sqft'}>,
#         <AxesSubplot:title={'center':'price'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
train_data['Bedrooms'] = np.log(train_data['Bedrooms']+1)
train_data['Bathrooms'] = np.log(train_data['Bathrooms']+1)
train_data['Balcony'] = np.log(train_data['Balcony']+1)
train_data['parking'] = np.log(train_data['parking']+1)

# %%
train_data.hist(figsize=(15,8))
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'area'}>,
#         <AxesSubplot:title={'center':'latitude'}>],
#        [<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'Bedrooms'}>,
#         <AxesSubplot:title={'center':'Bathrooms'}>],
#        [<AxesSubplot:title={'center':'Balcony'}>,
#         <AxesSubplot:title={'center':'parking'}>,
#         <AxesSubplot:title={'center':'Lift'}>],
#        [<AxesSubplot:title={'center':'Price_sqft'}>,
#         <AxesSubplot:title={'center':'price'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
train_data = train_data.join(pd.get_dummies(train_data.Furnished_status)).drop(['Furnished_status'], axis=1)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(x="latitude", y="longitude", data=train_data, hue="price", palette="coolwarm")
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='longitude'>

# %%
train_data

# %%
test_data = x_test.join(y_test)

test_data['Bedrooms'] = np.log(test_data['Bedrooms']+1)
test_data['Bathrooms'] = np.log(test_data['Bathrooms']+1)
test_data['Balcony'] = np.log(test_data['Balcony']+1)
test_data['parking'] = np.log(test_data['parking']+1)

test_data = test_data.join(pd.get_dummies(test_data.Furnished_status)).drop(['Furnished_status'], axis=1)

# %%
x_test, y_test = test_data.drop(['price'], axis=1), test_data['price']

# %%
reg.score(x_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4216\3493899247.py in <module>
# ----> 1 reg.score(x_test, y_test)
#
# NameError: name 'reg' is not defined
